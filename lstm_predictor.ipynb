# %% [markdown]
# # LSTM Stock Predictor Using Closing Prices

# %% [markdown]
# ## Data Preparation
#
# In this section, we will prepare the training and testing data for the LSTM model.
#
# We will need to:
# 1. Use the `window_data` function to generate the X and y values for the model.
# 2. Split the data into 70% training and 30% testing
# 3. Apply the MinMaxScaler to the `X` and `y` values
# 4. Reshape the `X_train` and `X_test` data for the model.
#
# **Note:** The required input format for the LSTM is:
#
# ```python
# reshape((X_train.shape[0], X_train.shape[1], 1))
# ```

# %%
# Initial imports
import numpy as np
import pandas as pd
import datetime
import tensorflow as tf
from pathlib import Path
import keras_tuner as kt

# %matplotlib inline

# %%
# Set the random seed for reproducibility
# Note: This is used for model prototyping, but it is good practice to comment this out and run multiple experiments to evaluate your model.
from numpy.random import seed

seed(1)
from tensorflow import random

random.set_seed(2)

# %% [markdown]
# ### Data Loading
#
# In this activity, we will use closing prices from different stocks to make predictions of future closing prices based on the temporal data of each stock.

# %%
import yfinance as yf

btcdata = yf.download("ETH-USD", start="2020-04-01", end="2022-04-07")
df = pd.DataFrame(btcdata)
df.drop(columns=['Adj Close'],inplace=True)

df.head(20)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close       Volume
# Date
# 2020-04-01  133.612320  135.634552  129.730942  135.634552  12456564435
# 2020-04-02  135.732178  146.787094  135.732178  142.029144  15322861686
# 2020-04-03  142.110458  146.899872  139.619385  142.091309  13184603402
# 2020-04-04  142.215179  145.377304  140.121826  145.219391  11946658257
# 2020-04-05  145.261017  146.128525  142.102081  143.546646  11280993591
# 2020-04-06  143.608215  169.272644  143.544601  169.135880  21636382525
# 2020-04-07  169.147446  175.204132  164.203323  165.101944  21659346091
# 2020-04-08  165.240326  173.210266  164.493195  172.641739  17063110836
# 2020-04-09  172.761261  172.897781  167.987122  170.807144  14901696210
# 2020-04-10  170.829269  170.949768  154.914474  158.412445  17980944616
# 2020-04-11  158.538986  161.167572  155.298340  158.216019  13555089447
# 2020-04-12  158.232391  164.516953  156.320511  161.142426  15123721386
# 2020-04-13  160.720673  160.749695  151.614487  156.279556  16465282133
# 2020-04-14  156.355957  160.944275  155.865936  157.596390  14723156630
# 2020-04-15  157.565643  160.711121  152.802841  153.286896  14171753737
# 2020-04-16  153.200424  173.157272  150.359421  172.157379  22910469236
# 2020-04-17  172.279419  174.275909  169.751572  171.638580  16714684266
# 2020-04-18  171.618073  187.940475  171.618073  186.914001  20160323443
# 2020-04-19  186.861984  188.098923  180.120819  181.614960  19146038381
# 2020-04-20  181.480225  186.083542  170.321274  172.297165  21266681335

# %%
df.Close.plot(figsize=(50, 20))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Creating the Features `X` and Target `y` Data
#
# The first step towards preparing the data is to create the input features vectors `X` and the target vector `y`. We will use the `window_data()` function to create these vectors.
#
# This function chunks the data up with a rolling window of _X<sub>t</sub> - window_ to predict _X<sub>t</sub>_.
#
# The function returns two `numpy` arrays:
#
# * `X`: The input features vectors.
#
# * `y`: The target vector.
#
# The function has the following parameters:
#
# * `df`: The original DataFrame with the time series data.
#
# * `window`: The window size in days of previous closing prices that will be used for the prediction.
#
# * `feature_col_number`: The column number from the original DataFrame where the features are located.
#
# * `target_col_number`: The column number from the original DataFrame where the target is located.

# %%
def window_data(df, window, feature_col_number, target_col_number):
    """
    This function accepts the column number for the features (X) and the target (y).
    It chunks the data up with a rolling window of Xt - window to predict Xt.
    It returns two numpy arrays of X and y.
    """
    X = []
    y = []
    for i in range(len(df) - window):
        features = df.iloc[i : (i + window), feature_col_number]
        target = df.iloc[(i + window), target_col_number]
        X.append(features)
        y.append(target)
    return np.array(X), np.array(y).reshape(-1, 1)

# %%
# Creating the features (X) and target (y) data using the window_data() function.
window_size = 10

feature_column = 3
target_column = 3
X, y = window_data(df, window_size, feature_column, target_column)
print (f"X sample values:\n{X[:5]} \n")
print (f"y sample values:\n{y[:5]}")
# Out:
# X sample values:
# [[135.634552   142.02914429 142.09130859 145.21939087 143.54664612
#   169.13587952 165.10194397 172.64173889 170.80714417 158.41244507]
#  [142.02914429 142.09130859 145.21939087 143.54664612 169.13587952
#   165.10194397 172.64173889 170.80714417 158.41244507 158.21601868]
#  [142.09130859 145.21939087 143.54664612 169.13587952 165.10194397
#   172.64173889 170.80714417 158.41244507 158.21601868 161.14242554]
#  [145.21939087 143.54664612 169.13587952 165.10194397 172.64173889
#   170.80714417 158.41244507 158.21601868 161.14242554 156.27955627]
#  [143.54664612 169.13587952 165.10194397 172.64173889 170.80714417
#   158.41244507 158.21601868 161.14242554 156.27955627 157.59638977]]
#
# y sample values:
# [[158.21601868]
#  [161.14242554]
#  [156.27955627]
#  [157.59638977]
#  [153.28689575]]

# %%
df.head(20)
# Out:
#                   Open        High         Low       Close       Volume
# Date
# 2020-04-01  133.612320  135.634552  129.730942  135.634552  12456564435
# 2020-04-02  135.732178  146.787094  135.732178  142.029144  15322861686
# 2020-04-03  142.110458  146.899872  139.619385  142.091309  13184603402
# 2020-04-04  142.215179  145.377304  140.121826  145.219391  11946658257
# 2020-04-05  145.261017  146.128525  142.102081  143.546646  11280993591
# 2020-04-06  143.608215  169.272644  143.544601  169.135880  21636382525
# 2020-04-07  169.147446  175.204132  164.203323  165.101944  21659346091
# 2020-04-08  165.240326  173.210266  164.493195  172.641739  17063110836
# 2020-04-09  172.761261  172.897781  167.987122  170.807144  14901696210
# 2020-04-10  170.829269  170.949768  154.914474  158.412445  17980944616
# 2020-04-11  158.538986  161.167572  155.298340  158.216019  13555089447
# 2020-04-12  158.232391  164.516953  156.320511  161.142426  15123721386
# 2020-04-13  160.720673  160.749695  151.614487  156.279556  16465282133
# 2020-04-14  156.355957  160.944275  155.865936  157.596390  14723156630
# 2020-04-15  157.565643  160.711121  152.802841  153.286896  14171753737
# 2020-04-16  153.200424  173.157272  150.359421  172.157379  22910469236
# 2020-04-17  172.279419  174.275909  169.751572  171.638580  16714684266
# 2020-04-18  171.618073  187.940475  171.618073  186.914001  20160323443
# 2020-04-19  186.861984  188.098923  180.120819  181.614960  19146038381
# 2020-04-20  181.480225  186.083542  170.321274  172.297165  21266681335

# %% [markdown]
# ### Splitting Data Between Training and Testing Sets
#
# To avoid the dataset being randomized, we will manually split the data using array slicing.

# %%
# Use 70% of the data for training and the remainder for testing
split = int(0.7 * len(X))
X_train = X[: split]
X_test = X[split:]
y_train = y[: split]
y_test = y[split:]

# %% [markdown]
# ### Scaling Data with `MinMaxScaler`
#
# Once the training and test datasets are created, we need to scale the data before training the LSTM model. We will use the `MinMaxScaler` from `sklearn` to scale all values between `0` and `1`.
#
# Note that we scale both features and target sets.

# %%
# Use the MinMaxScaler to scale data between 0 and 1.
from sklearn.preprocessing import MinMaxScaler

# Create a MinMaxScaler object
scaler = MinMaxScaler()

# Fit the MinMaxScaler object with the training feature data X_train
scaler.fit(X_train)

# Scale the features training and testing sets
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# Fit the MinMaxScaler object with the training target data y_train
scaler.fit(y_train)

# Scale the target training and testing sets
y_train = scaler.transform(y_train)
y_test = scaler.transform(y_test)

# %% [markdown]
# ### Reshape Features Data for the LSTM Model
#
# The LSTM API from Keras needs to receive the features data as a _vertical vector_, so that we need to reshape the `X` data in the form `reshape((X_train.shape[0], X_train.shape[1], 1))`.
#
# Both sets, training, and testing are reshaped.

# %%
# Reshape the features for the model
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))
print (f"X_train sample values:\n{X_train[:5]} \n")
print (f"X_test sample values:\n{X_test[:5]}")
# Out:
# X_train sample values:
# [[[0.00000000e+00]
#   [0.00000000e+00]
#   [0.00000000e+00]
#   [4.15572804e-04]
#   [0.00000000e+00]
#   [3.94703577e-03]
#   [2.94242322e-03]
#   [4.82013606e-03]
#   [4.36324803e-03]
#   [1.27646837e-03]]
#
#  [[1.58554095e-03]
#   [1.54381351e-05]
#   [7.76852584e-04]
#   [0.00000000e+00]
#   [6.35732945e-03]
#   [2.94242322e-03]
#   [4.82013606e-03]
#   [4.36324803e-03]
#   [1.27646837e-03]
#   [1.22755028e-03]]
#
#  [[1.60095461e-03]
#   [7.92278726e-04]
#   [3.61429981e-04]
#   [6.35732945e-03]
#   [5.35514791e-03]
#   [4.82013606e-03]
#   [4.36324803e-03]
#   [1.27646837e-03]
#   [1.22755028e-03]
#   [1.95634354e-03]]
#
#  [[2.37656349e-03]
#   [3.76862536e-04]
#   [6.71646170e-03]
#   [5.35514791e-03]
#   [7.22831697e-03]
#   [4.36324803e-03]
#   [1.27646837e-03]
#   [1.22755028e-03]
#   [1.95634354e-03]
#   [7.45293092e-04]]
#
#  [[1.96180596e-03]
#   [6.73179614e-03]
#   [5.71464238e-03]
#   [7.22831697e-03]
#   [6.77253454e-03]
#   [1.27646837e-03]
#   [1.22755028e-03]
#   [1.95634354e-03]
#   [7.45293092e-04]
#   [1.07323771e-03]]]
#
# X_test sample values:
# [[[0.77025282]
#   [0.78904568]
#   [0.7525847 ]
#   [0.76552804]
#   [0.73457523]
#   [0.77633682]
#   [0.76981258]
#   [0.76547912]
#   [0.76482454]
#   [0.81696322]]
#
#  [[0.78938016]
#   [0.75258852]
#   [0.76561278]
#   [0.73457523]
#   [0.77687805]
#   [0.76981258]
#   [0.76547912]
#   [0.76482454]
#   [0.81696322]
#   [0.91685215]]
#
#  [[0.7529808 ]
#   [0.7656164 ]
#   [0.73467116]
#   [0.77687805]
#   [0.7703696 ]
#   [0.76547912]
#   [0.76482454]
#   [0.81696322]
#   [0.91685215]
#   [0.90593469]]
#
#  [[0.76598802]
#   [0.73467525]
#   [0.77695869]
#   [0.7703696 ]
#   [0.76604662]
#   [0.76482454]
#   [0.81696322]
#   [0.91685215]
#   [0.90593469]
#   [0.94319729]]
#
#  [[0.73509594]
#   [0.77696213]
#   [0.77045259]
#   [0.76604662]
#   [0.76539363]
#   [0.81696322]
#   [0.91685215]
#   [0.90593469]
#   [0.94319729]
#   [0.93005135]]]

# %% [markdown]
# ---
#
# ## Build and Train the LSTM RNN
#
# In this section, we will design a custom LSTM RNN in Keras and fit (train) it using the training data we defined.
#
# We will need to:
#
# 1. Define the model architecture in Keras.
#
# 2. Compile the model.
#
# 3. Fit the model to the training data.

# %% [markdown]
# ### Importing the Keras Modules
#
# The LSTM RNN model in Keras uses the `Sequential` model and the `LSTM` layer as we did before. However, there is a new type of layer called `Dropout`.
#
# * `Dropout`: Dropout is a regularization technique for reducing overfitting in neural networks. This type of layer applies the dropout technique to the input.

# %%
# Import required Keras modules
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow import keras

# %% [markdown]
# ### Defining the LSTM RNN Model Structure
#
# We are just creating a model function here. This function is then used for hyper parameter tuning later.
#
# To create an LSTM RNN model, we will add `LSTM` layers. The `return_sequences` parameter needs to set to `True` every time we add a new `LSTM` layer, excluding the final layer. The `input_shape` is the number of time steps and the number of indicators
#
# After each `LSTM` layer, we add a `Dropout` layer to prevent overfitting. The parameter passed to the `Dropout` layer is the fraction of nodes that will be drop on each epoch, for this demo, we will use a dropout value of `0.2`, it means that on each epoch we will randomly drop `20%` of the units.
#
# We will compile the model, using the `adam` optimizer, as loss function, we will use `mean_square_error` since the value we want to predict is continuous.

# %%
# Define the LSTM RNN model.
def model_builder(hp):
    model = Sequential()

    hp_units = hp.Int('units', min_value=2, max_value=218, step=32)
    dropout_fraction = 0.2
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    # Layer 1
    model.add(LSTM(
        units=hp_units,
        return_sequences=True,
        input_shape=(X_train.shape[1], 1))
        )
    model.add(Dropout(dropout_fraction))
    # Layer 2
    model.add(LSTM(units=hp_units, return_sequences=True))
    model.add(Dropout(dropout_fraction))
    # Layer 3
    model.add(LSTM(units=hp_units))
    model.add(Dropout(dropout_fraction))
    # Output layer
    model.add(Dense(1))
    model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate), loss="mean_squared_error",metrics=['accuracy'])
    model.summary()
    return model

# %% [markdown]
# ### Hyperparameter tuning the LSTM RNN Model

# %%
# remove the hyperparameter log dir
# !rm -rf my_dir

# %%
tuner = kt.Hyperband(model_builder,
                     objective = kt.Objective("val_loss", direction="min"),
                     max_epochs=40,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt')

stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
tuner.search(X_train, y_train, epochs=50, validation_split=0.2, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# Trial 17 Complete [00h 00m 05s]
# val_loss: 0.10989739000797272
#
# Best val_loss So Far: 0.005778406281024218
# Total elapsed time: 00h 01m 39s
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 130 and the optimal learning rate for the optimizer
# is 0.001.

# %% [markdown]
# ### Training the Model
#
# Once the model is defined, we train (fit) the model using `50` epochs.

# %%
model = tuner.hypermodel.build(best_hps)

# Retrain the model
training_history=model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 10, 130)           68640
#
#  dropout_3 (Dropout)         (None, 10, 130)           0
#
#  lstm_4 (LSTM)               (None, 10, 130)           135720
#
#  dropout_4 (Dropout)         (None, 10, 130)           0
#
#  lstm_5 (LSTM)               (None, 130)               135720
#
#  dropout_5 (Dropout)         (None, 130)               0
#
#  dense_1 (Dense)             (None, 1)                 131
#
# =================================================================
# Total params: 340,211
# Trainable params: 340,211
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 13/13 [==============================] - 5s 90ms/step - loss: 0.0254 - accuracy: 0.0049 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0054 - accuracy: 0.0049 - val_loss: 0.0057 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0035 - accuracy: 0.0049 - val_loss: 0.0058 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0025 - accuracy: 0.0049 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0030 - accuracy: 0.0049 - val_loss: 0.0077 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0032 - accuracy: 0.0049 - val_loss: 0.0056 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0030 - accuracy: 0.0049 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0027 - accuracy: 0.0049 - val_loss: 0.0059 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0028 - accuracy: 0.0049 - val_loss: 0.0053 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0026 - accuracy: 0.0049 - val_loss: 0.0062 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0032 - accuracy: 0.0049 - val_loss: 0.0059 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0027 - accuracy: 0.0049 - val_loss: 0.0053 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0034 - accuracy: 0.0049 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0024 - accuracy: 0.0049 - val_loss: 0.0046 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0026 - accuracy: 0.0049 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0028 - accuracy: 0.0049 - val_loss: 0.0044 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0028 - accuracy: 0.0049 - val_loss: 0.0044 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0025 - accuracy: 0.0049 - val_loss: 0.0043 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0015 - accuracy: 0.0049 - val_loss: 0.0042 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0027 - accuracy: 0.0049 - val_loss: 0.0041 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0017 - accuracy: 0.0049 - val_loss: 0.0045 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0021 - accuracy: 0.0049 - val_loss: 0.0051 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0021 - accuracy: 0.0049 - val_loss: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0020 - accuracy: 0.0049 - val_loss: 0.0041 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0018 - accuracy: 0.0049 - val_loss: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0022 - accuracy: 0.0049 - val_loss: 0.0090 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0031 - accuracy: 0.0049 - val_loss: 0.0051 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0042 - accuracy: 0.0049 - val_loss: 0.0086 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0033 - accuracy: 0.0049 - val_loss: 0.0077 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0020 - accuracy: 0.0049 - val_loss: 0.0036 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0026 - accuracy: 0.0049 - val_loss: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0028 - accuracy: 0.0049 - val_loss: 0.0038 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0037 - accuracy: 0.0049 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0021 - accuracy: 0.0049 - val_loss: 0.0031 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0017 - accuracy: 0.0049 - val_loss: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0018 - accuracy: 0.0049 - val_loss: 0.0062 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0018 - accuracy: 0.0049 - val_loss: 0.0029 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0013 - accuracy: 0.0049 - val_loss: 0.0042 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0015 - accuracy: 0.0049 - val_loss: 0.0028 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0015 - accuracy: 0.0049 - val_loss: 0.0029 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0019 - accuracy: 0.0049 - val_loss: 0.0025 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0023 - accuracy: 0.0049 - val_loss: 0.0041 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0014 - accuracy: 0.0049 - val_loss: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0016 - accuracy: 0.0049 - val_loss: 0.0024 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0016 - accuracy: 0.0049 - val_loss: 0.0025 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0012 - accuracy: 0.0049 - val_loss: 0.0029 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0011 - accuracy: 0.0049 - val_loss: 0.0027 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 13/13 [==============================] - 0s 17ms/step - loss: 9.3955e-04 - accuracy: 0.0049 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0016 - accuracy: 0.0049 - val_loss: 0.0060 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0013 - accuracy: 0.0049 - val_loss: 0.0028 - val_accuracy: 0.0000e+00

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in my_dir/intro_to_kt
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x7fe8bbccc450>
# Trial summary
# Hyperparameters:
# units: 130
# learning_rate: 0.001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.005778406281024218
# Trial summary
# Hyperparameters:
# units: 66
# learning_rate: 0.001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.006119919009506702
# Trial summary
# Hyperparameters:
# units: 194
# learning_rate: 0.01
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.00669828662648797
# Trial summary
# Hyperparameters:
# units: 162
# learning_rate: 0.001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.007785656489431858
# Trial summary
# Hyperparameters:
# units: 194
# learning_rate: 0.0001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.010246803984045982
# Trial summary
# Hyperparameters:
# units: 194
# learning_rate: 0.001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.010498167015612125
# Trial summary
# Hyperparameters:
# units: 34
# learning_rate: 0.001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.01738099567592144
# Trial summary
# Hyperparameters:
# units: 66
# learning_rate: 0.01
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.018217511475086212
# Trial summary
# Hyperparameters:
# units: 98
# learning_rate: 0.01
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.048980049788951874
# Trial summary
# Hyperparameters:
# units: 162
# learning_rate: 0.0001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 3
# tuner/round: 0
# Score: 0.0561019591987133

# %% [markdown]
# ---
# ## Model Performance
#
# In this section, we will evaluate the model using the test data.
#
# We will need to:
#
# 1. Evaluate the model using the `X_test` and `y_test` data.
#
# 2. Use the `X_test` data to make predictions.
#
# 3. Create a DataFrame of real (`y_test`) vs predicted values.
#
# 4. Plot the Real vs predicted values as a line chart.

# %% [markdown]
# ### Evaluate the Model
#
# It's time to evaluate our model to assess its performance. We will use the `evaluate` method using the testing data.

# %%
# Evaluate the model
eval_result = model.evaluate(X_test, y_test)
print("[test loss, test accuracy]:", eval_result)
# Out:
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 0.0000e+00
# [test loss, test accuracy]: [0.003360517555847764, 0.0]

# %% [markdown]
# ### Making Predictions
#
# We will make some closing price predictions using our brand new LSTM RNN model and our testing data.

# %%
# Make some predictions
predicted = model.predict(X_test)

# %% [markdown]
# Since we scaled the original values using the `MinMaxScaler`, we need to recover the original prices to better understand the predictions.
#
# We will use the `inverse_transform()` method of the scaler to decode the scaled values to their original scale.

# %%
# Recover the original prices instead of the scaled version
predicted_prices = scaler.inverse_transform(predicted)
real_prices = scaler.inverse_transform(y_test.reshape(-1, 1))

# %% [markdown]
# ### Plotting Predicted Vs. Real Prices
#
# To plot the predicted vs. the real values, we will create a DataFrame.

# %%
# Create a DataFrame of Real and Predicted values
stocks = pd.DataFrame({
    "Real": real_prices.ravel(),
    "Predicted": predicted_prices.ravel()
    }, index = df.index[-len(real_prices): ])
stocks.head()
# Out:
#                    Real    Predicted
# Date
# 2021-09-01  3834.828125  3326.662842
# 2021-09-02  3790.989990  3476.260498
# 2021-09-03  3940.614746  3677.884521
# 2021-09-04  3887.828369  3880.758545
# 2021-09-05  3952.133545  4035.301270

# %%
# Plot the real vs predicted prices as a line chart
plt=stocks.plot(title="LSTM", figsize=(50, 20))
plt.get_figure().savefig("LSTM.png")
plt
# Out:
# <AxesSubplot:title={'center':'LSTM'}, xlabel='Date'>

# %%
from sklearn import metrics

print(f'Mean Absolute Error:', round(metrics.mean_absolute_error(y_test, predicted), 4))
print(f'Mean Squared Error:', round(metrics.mean_squared_error(y_test, predicted), 4))
print(f'Root Mean Squared Error:', round(np.sqrt(metrics.mean_squared_error(y_test, predicted)), 4))
print(f'(R^2) Score:', round(metrics.r2_score(y_test, predicted), 4))
errors = abs(predicted - y_test)
mape = 100 * (errors / y_test)
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 0.0457
# Mean Squared Error: 0.0034
# Root Mean Squared Error: 0.058
# (R^2) Score: 0.8663
# Accuracy: 94.35 %.
